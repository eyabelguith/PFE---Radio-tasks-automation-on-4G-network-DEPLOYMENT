# %%
import requests

city = input("Enter city name: ")
api_key = '56bd3212a99808185e5d61c67a907279'

url = 'http://api.openweathermap.org/data/2.5/weather?q={}&appid={}&units=metric'.format(city, api_key)

res = requests.get(url)
data = res.json()

if res.status_code == 200:
    humidity = data['main']['humidity']
    wind = data['wind']['speed']
    temp = data['main']['temp']

    print('Temperature:', temp, '°C')
    print('Wind:', wind)
    print('Humidity:', humidity)
else:
    print("Error:", data["message"])
# Out:
# Enter city name: sfax
# Temperature: 33.08 °C
# Wind: 3.6
# Humidity: 49

# %%
import requests

# Step 1: Get the latitude and longitude of the city (if needed)
city = input("Enter city name: ")
api_key = '56bd3212a99808185e5d61c67a907279'

geo_url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}'
geo_res = requests.get(geo_url)
geo_data = geo_res.json()

if geo_res.status_code == 200:
    lat = geo_data['coord']['lat']
    lon = geo_data['coord']['lon']

    # Step 2: Get the 16-day forecast using the Daily Forecast API
    cnt = 16  # Number of days for the forecast
    forecast_url = f'http://api.openweathermap.org/data/2.5/forecast/daily?lat={lat}&lon={lon}&cnt={cnt}&appid={api_key}&units=metric'
    forecast_res = requests.get(forecast_url)
    forecast_data = forecast_res.json()

    if forecast_res.status_code == 200:
        daily_forecasts = forecast_data['list']
        
        for day in daily_forecasts:
            dt = day['dt']
            temp_day = day['temp']['day']
            humidity = day['humidity']
            wind_speed = day['speed']

            print(f'Date: {dt}')
            print(f'Temperature: {temp_day} °C')
            print(f'Humidity: {humidity} %')
            print(f'Wind Speed: {wind_speed} m/s')
            print('---')
    else:
        print("Error in getting forecast data:", forecast_data["message"])
else:
    print("Error in getting location data:", geo_data["message"])
# Out:
# Enter city name: sfax
# Date: 1721214000
# Temperature: 33.78 °C
# Humidity: 47 %
# Wind Speed: 4.68 m/s
# ---
# Date: 1721300400
# Temperature: 31.58 °C
# Humidity: 44 %
# Wind Speed: 7.21 m/s
# ---
# Date: 1721386800
# Temperature: 34.27 °C
# Humidity: 33 %
# Wind Speed: 9.56 m/s
# ---
# Date: 1721473200
# Temperature: 32.57 °C
# Humidity: 31 %
# Wind Speed: 4.57 m/s
# ---
# Date: 1721559600
# Temperature: 33.75 °C
# Humidity: 34 %
# Wind Speed: 7.16 m/s
# ---
# Date: 1721646000
# Temperature: 33.86 °C
# Humidity: 36 %
# Wind Speed: 9.5 m/s
# ---
# Date: 1721732400
# Temperature: 30.09 °C
# Humidity: 43 %
# Wind Speed: 5.8 m/s
# ---
# Date: 1721818800
# Temperature: 31.77 °C
# Humidity: 46 %
# Wind Speed: 5.59 m/s
# ---
# Date: 1721905200
# Temperature: 34.58 °C
# Humidity: 23 %
# Wind Speed: 7.29 m/s
# ---
# Date: 1721991600
# Temperature: 28.93 °C
# Humidity: 56 %
# Wind Speed: 7.94 m/s
# ---
# Date: 1722078000
# Temperature: 29.16 °C
# Humidity: 52 %
# Wind Speed: 5.74 m/s
# ...

# %%
import requests
from datetime import datetime

# Step 1: Get the latitude and longitude of the city (if needed)
city = input("Enter city name: ")
api_key = '56bd3212a99808185e5d61c67a907279'

geo_url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}'
geo_res = requests.get(geo_url)
geo_data = geo_res.json()

if geo_res.status_code == 200:
    lat = geo_data['coord']['lat']
    lon = geo_data['coord']['lon']

    # Step 2: Get the 16-day forecast using the Daily Forecast API
    cnt = 16  # Number of days for the forecast
    forecast_url = f'http://api.openweathermap.org/data/2.5/forecast/daily?lat={lat}&lon={lon}&cnt={cnt}&appid={api_key}&units=metric'
    forecast_res = requests.get(forecast_url)
    forecast_data = forecast_res.json()

    if forecast_res.status_code == 200:
        daily_forecasts = forecast_data['list']
        
        for day in daily_forecasts:
            dt = datetime.utcfromtimestamp(day['dt']).strftime('%Y-%m-%d')
            temp_day = day['temp']['day']
            humidity = day['humidity']
            wind_speed = day['speed']

            print(f'Date: {dt}')
            print(f'Temperature: {temp_day} °C')
            print(f'Humidity: {humidity} %')
            print(f'Wind Speed: {wind_speed} m/s')
            print('---')
    else:
        print("Error in getting forecast data:", forecast_data["message"])
else:
    print("Error in getting location data:", geo_data["message"])
# Out:
# Enter city name: sfax
# Date: 2024-07-17
# Temperature: 33.78 °C
# Humidity: 47 %
# Wind Speed: 4.68 m/s
# ---
# Date: 2024-07-18
# Temperature: 31.58 °C
# Humidity: 44 %
# Wind Speed: 7.21 m/s
# ---
# Date: 2024-07-19
# Temperature: 34.27 °C
# Humidity: 33 %
# Wind Speed: 9.56 m/s
# ---
# Date: 2024-07-20
# Temperature: 32.57 °C
# Humidity: 31 %
# Wind Speed: 4.57 m/s
# ---
# Date: 2024-07-21
# Temperature: 33.75 °C
# Humidity: 34 %
# Wind Speed: 7.16 m/s
# ---
# Date: 2024-07-22
# Temperature: 33.86 °C
# Humidity: 36 %
# Wind Speed: 9.5 m/s
# ---
# Date: 2024-07-23
# Temperature: 30.09 °C
# Humidity: 43 %
# Wind Speed: 5.8 m/s
# ---
# Date: 2024-07-24
# Temperature: 31.77 °C
# Humidity: 46 %
# Wind Speed: 5.59 m/s
# ---
# Date: 2024-07-25
# Temperature: 34.58 °C
# Humidity: 23 %
# Wind Speed: 7.29 m/s
# ---
# Date: 2024-07-26
# Temperature: 28.93 °C
# Humidity: 56 %
# Wind Speed: 7.94 m/s
# ---
# Date: 2024-07-27
# Temperature: 29.16 °C
# Humidity: 52 %
# Wind Speed: 5.74 m/s
# ...

# %%
import requests
from datetime import datetime
import pandas as pd

# Step 1: Get the latitude and longitude of the city (if needed)
city = input("Enter city name: ")
api_key = '56bd3212a99808185e5d61c67a907279'

geo_url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}'
geo_res = requests.get(geo_url)
geo_data = geo_res.json()

if geo_res.status_code == 200:
    lat = geo_data['coord']['lat']
    lon = geo_data['coord']['lon']

    # Step 2: Get the 16-day forecast using the Daily Forecast API
    cnt = 16  # Number of days for the forecast
    forecast_url = f'http://api.openweathermap.org/data/2.5/forecast/daily?lat={lat}&lon={lon}&cnt={cnt}&appid={api_key}&units=metric'
    forecast_res = requests.get(forecast_url)
    forecast_data = forecast_res.json()

    if forecast_res.status_code == 200:
        daily_forecasts = forecast_data['list']
        
        # Prepare a list to store the forecast data
        forecast_list = []

        for day in daily_forecasts:
            dt = datetime.utcfromtimestamp(day['dt']).strftime('%Y-%m-%d')
            temp_day = day['temp']['day']
            humidity = day['humidity']
            wind_speed = day['speed']

            forecast_list.append({
                'Date': dt,
                'Temperature (°C)': temp_day,
                'Humidity (%)': humidity,
                'Wind Speed (m/s)': wind_speed
            })

        # Create a DataFrame from the list
        df = pd.DataFrame(forecast_list)

        # Print the DataFrame
        print(df)
        
        # Optionally, save the DataFrame to a CSV file
        df.to_csv(f'{city}_16daysforecast.csv', index=False)
        
    else:
        print("Error in getting forecast data:", forecast_data["message"])
else:
    print("Error in getting location data:", geo_data["message"])
# Out:
# Enter city name: sfax
#           Date  Temperature (°C)  Humidity (%)  Wind Speed (m/s)
# 0   2024-07-17             33.78            47              4.68
# 1   2024-07-18             31.58            44              7.21
# 2   2024-07-19             34.27            33              9.56
# 3   2024-07-20             32.57            31              4.57
# 4   2024-07-21             33.75            34              7.16
# 5   2024-07-22             33.86            36              9.50
# 6   2024-07-23             30.09            43              5.80
# 7   2024-07-24             31.77            46              5.59
# 8   2024-07-25             34.58            23              7.29
# 9   2024-07-26             28.93            56              7.94
# 10  2024-07-27             29.16            52              5.74
# 11  2024-07-28             29.88            48              4.96
# 12  2024-07-29             30.74            46              5.21
# ...

# %%
import requests
from datetime import datetime
import pandas as pd

# List of cities to get the weather forecast for
cities = ['Tunis', 'Ariana', 'Sfax', 'Monastir', 'Nabeul', 'Bizerte']
api_key = '56bd3212a99808185e5d61c67a907279'

# Function to get the weather forecast for a specific city
def get_weather_forecast(city):
    geo_url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}'
    geo_res = requests.get(geo_url)
    geo_data = geo_res.json()

    if geo_res.status_code == 200:
        lat = geo_data['coord']['lat']
        lon = geo_data['coord']['lon']

        cnt = 16  # Number of days for the forecast
        forecast_url = f'http://api.openweathermap.org/data/2.5/forecast/daily?lat={lat}&lon={lon}&cnt={cnt}&appid={api_key}&units=metric'
        forecast_res = requests.get(forecast_url)
        forecast_data = forecast_res.json()

        if forecast_res.status_code == 200:
            daily_forecasts = forecast_data['list']
            
            forecast_list = []
            for day in daily_forecasts:
                dt = datetime.utcfromtimestamp(day['dt']).strftime('%Y-%m-%d')
                temp_day = day['temp']['day']
                humidity = day['humidity']
                wind_speed = day['speed']

                forecast_list.append({
                    'Date': dt,
                    'Temperature (°C)': temp_day,
                    'Humidity (%)': humidity,
                    'Wind Speed (m/s)': wind_speed
                })

            # Create a DataFrame from the list
            df = pd.DataFrame(forecast_list)
            return df
        else:
            print(f"Error in getting forecast data for {city}: {forecast_data['message']}")
    else:
        print(f"Error in getting location data for {city}: {geo_data['message']}")
    return None

# Loop through each city and get the forecast
for city in cities:
    print(f"Getting weather forecast for {city}...")
    df = get_weather_forecast(city)
    if df is not None:
        # Print the DataFrame
        print(df)
        
        # Save the DataFrame to a CSV file
        df.to_csv(f'{city}_16_day_forecast.csv', index=False)
# Out:
# Getting weather forecast for Tunis...
#           Date  Temperature (°C)  Humidity (%)  Wind Speed (m/s)
# 0   2024-07-17             40.63            14              7.57
# 1   2024-07-18             39.44            16              8.30
# 2   2024-07-19             39.42            13             10.15
# 3   2024-07-20             37.48            17              4.23
# 4   2024-07-21             42.01            11              5.04
# 5   2024-07-22             38.99            23             10.03
# 6   2024-07-23             37.61            21              8.85
# 7   2024-07-24             38.26            23              7.42
# 8   2024-07-25             37.36            23              8.57
# 9   2024-07-26             34.76            17              8.10
# 10  2024-07-27             35.41            27              8.09
# 11  2024-07-28             37.36            23              7.81
# 12  2024-07-29             38.99            21              7.39
# ...

# %%
import requests
from datetime import datetime
import pandas as pd

# List of cities to get the weather forecast for
cities = ['Tunis', 'Ariana', 'Sfax', 'Monastir', 'Nabeul', 'Bizerte']
api_key = '56bd3212a99808185e5d61c67a907279'

# Function to get the weather forecast for a specific city
def get_weather_forecast(city):
    geo_url = f'http://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}'
    geo_res = requests.get(geo_url)
    geo_data = geo_res.json()

    if geo_res.status_code == 200:
        lat = geo_data['coord']['lat']
        lon = geo_data['coord']['lon']

        cnt = 16  # Number of days for the forecast
        forecast_url = f'http://api.openweathermap.org/data/2.5/forecast/daily?lat={lat}&lon={lon}&cnt={cnt}&appid={api_key}&units=metric'
        forecast_res = requests.get(forecast_url)
        forecast_data = forecast_res.json()

        if forecast_res.status_code == 200:
            daily_forecasts = forecast_data['list']
            
            forecast_list = []
            for day in daily_forecasts:
                dt = datetime.utcfromtimestamp(day['dt']).strftime('%Y-%m-%d')
                temp_day = day['temp']['day']
                humidity = day['humidity']
                wind_speed = day['speed']

                forecast_list.append({
                    'City': city,
                    'Date': dt,
                    'Temperature (°C)': temp_day,
                    'Humidity (%)': humidity,
                    'Wind Speed (m/s)': wind_speed
                })

            return forecast_list
        else:
            print(f"Error in getting forecast data for {city}: {forecast_data['message']}")
    else:
        print(f"Error in getting location data for {city}: {geo_data['message']}")
    return []

# Initialize an empty list to hold the forecast data for all cities
all_forecasts = []

# Loop through each city and get the forecast
for city in cities:
    print(f"Getting weather forecast for {city}...")
    city_forecasts = get_weather_forecast(city)
    all_forecasts.extend(city_forecasts)

# Create a DataFrame from the combined forecast data
df = pd.DataFrame(all_forecasts)

# Print the DataFrame
print(df)

# Save the DataFrame to a CSV file
df.to_csv('Tunisian_Cities_16_day_forecast.csv', index=False)
# Out:
# Getting weather forecast for Tunis...
# Getting weather forecast for Ariana...
# Getting weather forecast for Sfax...
# Getting weather forecast for Monastir...
# Getting weather forecast for Nabeul...
# Getting weather forecast for Bizerte...
#        City        Date  Temperature (°C)  Humidity (%)  Wind Speed (m/s)
# 0     Tunis  2024-07-17             40.63            14              7.57
# 1     Tunis  2024-07-18             39.44            16              8.30
# 2     Tunis  2024-07-19             39.42            13             10.15
# 3     Tunis  2024-07-20             37.48            17              4.23
# 4     Tunis  2024-07-21             42.01            11              5.04
# ..      ...         ...               ...           ...               ...
# 91  Bizerte  2024-07-28             28.17            52              5.64
# 92  Bizerte  2024-07-29             30.71            52              7.36
# ...

# %%
# !pip install flask nltk spacy
# Out:
# ...
#   Using cached spacy-3.7.5-cp311-cp311-win_amd64.whl.metadata (27 kB)
# ...
#   Using cached spacy_legacy-3.0.12-py2.py3-none-any.whl.metadata (2.8 kB)
# ...
#   Using cached spacy_loggers-1.0.5-py3-none-any.whl.metadata (23 kB)
# ...
#   Using cached murmurhash-1.0.10-cp311-cp311-win_amd64.whl.metadata (2.0 kB)
# ...
#   Using cached cymem-2.0.8-cp311-cp311-win_amd64.whl.metadata (8.6 kB)
# ...
#   Using cached preshed-3.0.9-cp311-cp311-win_amd64.whl.metadata (2.2 kB)
# ...
#   Using cached thinc-8.2.5-cp311-cp311-win_amd64.whl.metadata (15 kB)
# ...
#   Using cached wasabi-1.1.3-py3-none-any.whl.metadata (28 kB)
# ...
#   Using cached srsly-2.4.8-cp311-cp311-win_amd64.whl.metadata (20 kB)
# ...
#   Using cached catalogue-2.0.10-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached weasel-0.4.1-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached typer-0.12.3-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached langcodes-3.4.0-py3-none-any.whl.metadata (29 kB)
# ...
#   Using cached language_data-1.2.0-py3-none-any.whl.metadata (4.3 kB)
# ...

# %%
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ---------------------------------------- 0.0/12.8 MB ? eta -:--:--
#      ---------------------------------------- 0.0/12.8 MB 1.4 MB/s eta 0:00:10
#      ---------------------------------------- 0.1/12.8 MB 1.7 MB/s eta 0:00:08
#       --------------------------------------- 0.2/12.8 MB 1.5 MB/s eta 0:00:09
#      - -------------------------------------- 0.3/12.8 MB 2.0 MB/s eta 0:00:07
#      - -------------------------------------- 0.5/12.8 MB 2.5 MB/s eta 0:00:06
#      - -------------------------------------- 0.5/12.8 MB 2.5 MB/s eta 0:00:06
#      -- ------------------------------------- 0.7/12.8 MB 2.4 MB/s eta 0:00:05
#      -- ------------------------------------- 0.8/12.8 MB 2.2 MB/s eta 0:00:06
#      -- ------------------------------------- 0.8/12.8 MB 2.2 MB/s eta 0:00:06
#      -- ------------------------------------- 0.9/12.8 MB 2.1 MB/s eta 0:00:06
#      --- ------------------------------------ 1.0/12.8 MB 2.0 MB/s eta 0:00:06
# ...

# %%
import nltk
import spacy
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk import FreqDist

nltk.download('punkt')
nltk.download('stopwords')
nlp = spacy.load('en_core_web_sm')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\eyawo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\eyawo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import spacy
import pandas as pd
from spacy.util import minibatch, compounding
from pathlib import Path

# Load the data
df = pd.read_csv("network_issues.csv", encoding='latin1', header=None, names=['issue', 'classification'], usecols=[0, 1])

# %%
# Create training data in the format Spacy requires
train_data = []
for index, row in df.iterrows():
    train_data.append((row['issue'], {'cats': {'internal': row['classification'] == 'internal', 'external': row['classification'] == 'external'}}))

# %%
# Load Spacy model
nlp = spacy.blank('en')

# %%
# The textcat component is already in the pipeline, so just access it
textcat = nlp.get_pipe('textcat')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 2
#       1 # The textcat component is already in the pipeline, so just access it
# ----> 2 textcat = nlp.get_pipe('textcat')
#
# File ~\anaconda3\Lib\site-packages\spacy\language.py:650, in Language.get_pipe(self, name)
#     648     if pipe_name == name:
#     649         return component
# --> 650 raise KeyError(Errors.E001.format(name=name, opts=self.component_names))
#
# KeyError: "[E001] No component 'textcat' found in pipeline. Available names: []"

# %%
# Add labels to text classifier
textcat.add_label('internal')
textcat.add_label('external')
# Out:
# 0

# %%
import spacy
from spacy.training.example import Example

# Train the model
optimizer = nlp.begin_training()
for i in range(10):  # Adjust the number of iterations as needed
    losses = {}
    batches = minibatch(train_data, size=compounding(4.0, 32.0, 1.001))
    for batch in batches:
        examples = []
        for text, annotations in batch:
            if not isinstance(text, str):
                continue  # Skip this iteration if text is not a string
            doc = nlp.make_doc(str(text))  # Ensure text is a string
            example = Example.from_dict(doc, annotations)
            examples.append(example)
        nlp.update(examples, sgd=optimizer, losses=losses)
    print(f"Iteration {i}, Losses: {losses}")
# Out:
# Iteration 0, Losses: {'textcat': 2.5}
# Iteration 1, Losses: {'textcat': 2.5}
# Iteration 2, Losses: {'textcat': 2.5}
# Iteration 3, Losses: {'textcat': 2.5}
# Iteration 4, Losses: {'textcat': 2.5}
# Iteration 5, Losses: {'textcat': 2.5}
# Iteration 6, Losses: {'textcat': 2.5}
# Iteration 7, Losses: {'textcat': 2.5}
# Iteration 8, Losses: {'textcat': 2.5}
# Iteration 9, Losses: {'textcat': 2.5}

# %%
# Save the model
output_dir = Path("network_model")
nlp.to_disk(output_dir)

# %%
import spacy
import pandas as pd
from spacy.training.example import Example
from spacy.util import minibatch, compounding
from pathlib import Path

# Load the data
df = pd.read_csv("network_issues.csv", encoding='latin1', header=None, names=['issue', 'classification', 'solution'], usecols=[0, 1])

# Create training data
train_data = []
for _, row in df.iterrows():
    train_data.append((row['issue'], {'cats': {'internal': row['classification'] == 'internal', 'external': row['classification'] == 'external'}}))

# Load Spacy model
nlp = spacy.blank('en')

# Add text classifier
textcat = nlp.add_pipe('textcat', last=True)
textcat.add_label('internal')
textcat.add_label('external')

# Train the model
optimizer = nlp.begin_training()
for i in range(10):
    losses = {}
    batches = minibatch(train_data, size=compounding(4.0, 32.0, 1.001))
    for batch in batches:
        examples = []
        for text, annotations in batch:
            doc = nlp.make_doc(str(text))  # Ensure text is a string
            example = Example.from_dict(doc, annotations)
            examples.append(example)
        nlp.update(examples, drop=0.5, sgd=optimizer, losses=losses)
    print(f"Iteration {i}, Losses: {losses}")

# Save the model
output_dir = Path("network_model")
nlp.to_disk(output_dir)
# Out:
# Iteration 0, Losses: {'textcat': 2.75}
# Iteration 1, Losses: {'textcat': 2.75}
# Iteration 2, Losses: {'textcat': 2.75}
# Iteration 3, Losses: {'textcat': 2.75}
# Iteration 4, Losses: {'textcat': 2.75}
# Iteration 5, Losses: {'textcat': 2.75}
# Iteration 6, Losses: {'textcat': 2.75}
# Iteration 7, Losses: {'textcat': 2.75}
# Iteration 8, Losses: {'textcat': 2.75}
# Iteration 9, Losses: {'textcat': 2.75}

# %%
import spacy
import pandas as pd
from spacy.training.example import Example
from spacy.util import minibatch, compounding
from pathlib import Path

# Load the data
df = pd.read_csv("network_issues.csv", encoding='latin1', header=None, names=['issue', 'classification', 'solution'], usecols=[0, 1])

# Add explicit examples for greetings and farewells
extra_data = [
    ("hi", "greeting"),
    ("hello", "greeting"),
    ("hey", "greeting"),
    ("bye", "farewell"),
    ("goodbye", "farewell"),
    ("see you later", "farewell")
]

# Combine with your existing data
train_data = [(text, {'cats': {'internal': classification == 'internal', 'external': classification == 'external'}}) 
              for text, classification in df[['issue', 'classification']].values]

# Add extra examples
train_data += [(text, {'cats': {label: 1.0}}) for text, label in extra_data]

# Load Spacy model
nlp = spacy.blank('en')

# Add text classifier
textcat = nlp.add_pipe('textcat', last=True)
textcat.add_label('internal')
textcat.add_label('external')

# Train the model
optimizer = nlp.begin_training()
for i in range(10):
    losses = {}
    batches = minibatch(train_data, size=compounding(4.0, 32.0, 1.001))
    for batch in batches:
        examples = []
        for text, annotations in batch:
            doc = nlp.make_doc(str(text))
            example = Example.from_dict(doc, annotations)
            examples.append(example)
        nlp.update(examples, drop=0.5, sgd=optimizer, losses=losses)
    print(f"Iteration {i}, Losses: {losses}")

# Save the model
output_dir = Path("network_model")
nlp.to_disk(output_dir)
# Out:
# Iteration 0, Losses: {'textcat': 3.75}
# Iteration 1, Losses: {'textcat': 3.75}
# Iteration 2, Losses: {'textcat': 3.75}
# Iteration 3, Losses: {'textcat': 3.75}
# Iteration 4, Losses: {'textcat': 3.75}
# Iteration 5, Losses: {'textcat': 3.75}
# Iteration 6, Losses: {'textcat': 3.75}
# Iteration 7, Losses: {'textcat': 3.75}
# Iteration 8, Losses: {'textcat': 3.75}
# Iteration 9, Losses: {'textcat': 3.75}

# %%
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
from transformers import BertTokenizer, BertForSequenceClassification, AdamW, get_linear_schedule_with_warmup
from sklearn.model_selection import train_test_split

# Load and prepare the data
df = pd.read_csv("network_issues.csv", encoding='latin1', header=None, names=['issue', 'classification', 'solution'], usecols=[0, 1])

# Handle NaN values
df['issue'].fillna("Unknown issue", inplace=True)

# Convert classification to labels
df['label'] = df['classification'].apply(lambda x: 1 if x == 'internal' else 0)  # 0 for external, 1 for internal

# Define a custom dataset
class CustomDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_len):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_len = max_len
    
    def __len__(self):
        return len(self.texts)
    
    def __getitem__(self, idx):
        text = self.texts[idx]
        label = self.labels[idx]
        encodings = self.tokenizer.encode_plus(
            text,
            add_special_tokens=True,
            max_length=self.max_len,
            padding='max_length',
            truncation=True,
            return_tensors='pt'
        )
        return {
            'input_ids': encodings['input_ids'].flatten(),
            'attention_mask': encodings['attention_mask'].flatten(),
            'labels': torch.tensor(label, dtype=torch.long)
        }

# Initialize tokenizer and model
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
model = BertForSequenceClassification.from_pretrained('bert-base-uncased', num_labels=2)

# Prepare the dataset
texts = df['issue'].tolist()
labels = df['label'].tolist()
train_texts, val_texts, train_labels, val_labels = train_test_split(texts, labels, test_size=0.2)

train_dataset = CustomDataset(train_texts, train_labels, tokenizer, max_len=128)
val_dataset = CustomDataset(val_texts, val_labels, tokenizer, max_len=128)

# DataLoader
train_dataloader = DataLoader(train_dataset, batch_size=8, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=8)

# Define optimizer and scheduler
optimizer = AdamW(model.parameters(), lr=2e-5)
total_steps = len(train_dataloader) * 3  # 3 epochs
scheduler = get_linear_schedule_with_warmup(
    optimizer,
    num_warmup_steps=0,
    num_training_steps=total_steps
)

# Training loop
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model.to(device)

for epoch in range(3):  # 3 epochs
    model.train()
    for batch in train_dataloader:
        optimizer.zero_grad()
        input_ids = batch['input_ids'].to(device)
        attention_mask = batch['attention_mask'].to(device)
        labels = batch['labels'].to(device)
        
        outputs = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        loss = outputs.loss
        loss.backward()
        optimizer.step()
        scheduler.step()
    
    # Evaluate the model (optional)
    model.eval()
    # Add evaluation code here

# Save the model
model.save_pretrained('chatbot_model')
tokenizer.save_pretrained('chatbot_model')
# Out:
# C:\Users\eyawo\anaconda3\Lib\site-packages\transformers\tokenization_utils_base.py:1601: FutureWarning: `clean_up_tokenization_spaces` was not set. It will be set to `True` by default. This behavior will be depracted in transformers v4.45, and will be then set to `False` by default. For more details check this issue: https://github.com/huggingface/transformers/issues/31884
#   warnings.warn(
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# A parameter name that contains `beta` will be renamed internally to `bias`. Please use a different name to suppress this warning.
# A parameter name that contains `gamma` will be renamed internally to `weight`. Please use a different name to suppress this warning.
# ...
